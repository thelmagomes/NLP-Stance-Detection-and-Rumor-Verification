# %% [markdown]
# # ANOTHER APPROACH (USING PRE-TRAINED MODEL)

# %%
! pip install transformers -q
# Out:
#      |████████████████████████████████| 4.2 MB 5.4 MB/s
#      |████████████████████████████████| 6.6 MB 11.3 MB/s
#      |████████████████████████████████| 84 kB 1.4 MB/s
#      |████████████████████████████████| 596 kB 38.5 MB/s

# %% [markdown]
# DATA PRE-PROCESSING TO SEPARATE TWEETS AS PER LABEL

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

path = "/content/training_task_c_tweets.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                    id  in_reply_to_status_id_str  \
# 0  552785374507175936         552783667052167168
# 1  552786226546495488         552785374507175936
# 2  552789345628069888         552786226546495488
# 3  552792862610694144         552783667052167168
# 4  552943855021330432         552783667052167168
#
#                                                 text  user.verified  \
# 0  MT @euronews France: 10 dead after shooting at...          False
# 1  @j0nathandavis They who? Stupid and partial op...          False
# 2  @nanoSpawn Socialists, Antisemites, anti zioni...          False
# 3  @euronews @TradeDesk_Steve A French crime of p...          False
# 4  @euronews LOL. 5 million Muslims in France, wh...          False
#
#    user.followers_count  retweet_count  favorite_count  \
# 0                  1828              1               2
# 1                   405              0               0
# 2                  1828              0               0
# 3                    26              0               0
# 4                    14              0               0
#
#                                  entities.hashtags entities.urls    label  \
# 0  [{'indices': [70, 83], 'text': 'CharlieHebdo'}]            []  comment
# 1                                               []            []     deny
# 2                                               []            []  comment
# 3                                               []            []    query
# 4                                               []            []  comment
#
#                                    parent_tweet_text
# 0  France: 10 people dead after shooting at HQ of...
# 1  MT @euronews France: 10 dead after shooting at...
# 2  @j0nathandavis They who? Stupid and partial op...
# 3  France: 10 people dead after shooting at HQ of...
# 4  France: 10 people dead after shooting at HQ of...

# %%
# df1 is a data frame which groups all the reply tweets as per their parent tweet

df1 = df.groupby(by=['in_reply_to_status_id_str', 'label'])['text'].apply(list).reset_index(name='text_list')

# %%
df1.to_csv('temp_grouped_output.csv')
df1
# Out:
#       in_reply_to_status_id_str    label  \
# 0            498280126254428160  comment
# 1            498280126254428160  support
# 2            498430783699554305  comment
# 3            498430783699554305  support
# 4            498432131669192704  comment
# ...                         ...      ...
# 2138         581473088249958400  comment
# 2139         581473088249958400    query
# 2140         581473088249958400  support
# 2141         581573165492523008     deny
# 2142         581574401411457024  comment
#
#                                               text_list
# 0     [@MichaelSkolnik -- wow, @MichaelSkolnik Unbel...
# 1     [“@MichaelSkolnik: Mike Brown was staying with...
# 2     [@MichaelSkolnik cool! Darkskinned man is a cr...
# 3     [@MichaelSkolnik @AC_BOwen #Cleveland @CivilRi...
# 4     [@Agent_Kindi&lt;&lt;&lt;&lt; @SecretService I...
# ...                                                 ...
# 2138  [@jjauthor @gatewaypundit. I knew it! Those cr...
# 2139  [@jjauthor @gatewaypundit Isn't Islam a wonder...
# 2140  [@jjauthor @gatewaypundit i knew that scarf he...
# 2141  [@EdWardMDBlog @USATODAY @khjelmgaard all rumo...
# 2142  [@tinkalee_12 @USATODAY @khjelmgaard My 2nd so...
#
# [2143 rows x 3 columns]

# %%
#check type of the data df1

print(type(df1))
df1.columns.tolist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ['in_reply_to_status_id_str', 'label', 'text_list']

# %%
#test
df1[(df1['label'] == 'support')]
# Out:
#       in_reply_to_status_id_str    label  \
# 1            498280126254428160  support
# 3            498430783699554305  support
# 5            498433698149056513  support
# 12           499366666300846081  support
# 16           499368931367608320  support
# ...                         ...      ...
# 2121         581075660690575360  support
# 2128         581293286268129280  support
# 2132         581298086246395904  support
# 2136         581386094337474560  support
# 2140         581473088249958400  support
#
#                                               text_list
# 1     [“@MichaelSkolnik: Mike Brown was staying with...
# 3     [@MichaelSkolnik @AC_BOwen #Cleveland @CivilRi...
# 5       [@Supreme___Power @MichaelSkolnik You so edgy.]
# 12    [Line of police cars with high beams on greets...
# 16    [@clydetheslyde @moiskd Imagine if Ferguson fo...
# ...                                                 ...
# 2121  [@marcepa49 The autopilot wasn't set to 100 fe...
# 2128  [@daxtonbrown @ItsJustJill. It took long enoug...
# 2132  [@daxtonbrown @AnewTrackrecord @ShamNaarai I w...
# 2136  [RT @khjelmgaard: German media reporting #Andr...
# 2140  [@jjauthor @gatewaypundit i knew that scarf he...
#
# [427 rows x 3 columns]

# %%
# Separate the tweet data as per their SDQC labels for text summarization into 4 csv files respectively

support_df = (df1[(df1['label'] == 'support')])
support_df.to_csv('support_tweets.csv')

deny_df = (df1[(df1['label'] == 'deny')])
deny_df.to_csv('deny_tweets.csv')

query_df = (df1[(df1['label'] == 'query')])
query_df.to_csv('query_tweets.csv')

comment_df = (df1[(df1['label'] == 'comment')])
comment_df.to_csv('comment_tweets.csv')

# %% [markdown]
# REPLY TEXT SUMMARIZATION FROM REPLIES PER SOURCE TWEET

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# %%
model_name = "snrspeaks/t5-one-line-summary"
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]

# %%
# function to generate a summary of reply tweets per source tweet

def summarize_tweet_transformers(input_df):
  list_of_generated_reply = []
  
  for rowIndex, row in input_df.iterrows(): #iterate over rows
    # print ('in rowIndex: ' + str(rowIndex))
    reply_abstract = """"""
    for columnIndex, value in row.items():
      if columnIndex == 'text_list':
        
        value = value.strip('][').split(', ')
        # print(type(value))
        # print(value)
        for line in value:
          reply_abstract += line + '\n'

        input_ids = tokenizer.encode(
         "summarize: " + reply_abstract, return_tensors="pt", add_special_tokens=True)
  
        generated_ids = model.generate(
          input_ids=input_ids,
          num_beams=5,
          max_length=100,
          repetition_penalty=2.5,
          length_penalty=1,
          early_stopping=True,
          num_return_sequences=3,)

        predicted_summary = [ 
                       tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=True)
                       for g in generated_ids
                       ]
        summarized_reply = predicted_summary[0]
        print(summarized_reply)
        list_of_generated_reply.append(summarized_reply)

  return list_of_generated_reply

# %% [markdown]
# # SUPPORT TWEETS

# %%
# support_df
import pandas as pd

support_path = '/content/support_tweets.csv'
support_df = pd.read_csv(support_path)

list_of_generated_reply = summarize_tweet_transformers(support_df)
print('type of list_of_reply: ' + str(type(list_of_generated_reply)))
# list_of_generated_reply = list_of_reply.strip('][').split(', ')

support_df['generated_reply'] = pd.Series(list_of_generated_reply)
print(support_df.dtypes)
# Out:
# 'Mike Brown was staying with his grandmother for the summer who lived in the community'
# 'Witness: Police stopped Mike Brown after yelling at him to walk on sidewalk
# '@Supreme__Power @Michael Skolnik You so edgy
# The line of police cars with high beams on #Ferguson
# Footprints of the #Ferguson protests
# "Hope to god"
# 'St. Louis Co. Police tell me of a man who pointed handgun at Chambers &amp; Sheffingdell at about 1 a.m. Man in critical
# A woman in #Ferguson was shot in head last night and released this selfie
# '@Michael Skolnik Shooting Related to Protesting
# A RePUBLICAN POLITICIANS INFOMERCIAL
# Where's Al Jesse?
# '@PhilSerrin Uh Sorry
# 'Name of #Ferguson cop expected to be released by 9 ET police chief'
# Darren Wilson is the one shot to kill Michael Brown
# 'URGENT: Darren Wilson is the police officer who shot Mike Brown
# Why didn't he get out of the car?
# Michael Brown was a Suspect in a Robbery
# Unarmed teen's first: killing unarmed teen his first
# 'Police reports released today indicate Mike Brown was a suspect in a "strong-armed" robbery in #Ferguson
# '#Mike Brown wanted to walk down the street, and his silence in death made him a criminal'
# 'BREAKING NEWS: Mike Brown is connected to an earlier robbery #Ferguson
# '@bonedog84 @DIANAZOGA @AntonioFrench exactly'
# 'Another look at the kid's clothes'
# '@enjen99 @DIANAZOGA oh yes
# Why a cop shoots and kills an unarmed man hands up?
# '@IamLauren Gill @DIANAZOGA Exactly'
# 'Update: #Ferguson police release stills from convenience store footage showing robbery'
# Look at the shoes
# Had the same flip flops on?
# A Note on 'Theoretical Structures of Electroweak Symmetry Breaking'
# '@zadiaz @mashable YES it was justified'
# '@YourAnonLive @OpFerguson so not even a felony
# 'If he stole a case of cigars where were they?'
# 'TYPICAL OF COWARDS AND BULIES @AlwaysThink How @DanteB4u'
# On the alleged robbery of Michael Brown in Ferguson
# Why did the #Ferguson officer not call for backup?
# Is there video surveillance at the #Ferguson Market?
# "Another Way to Live"
# 'Shoot unarmed kid.'
# "Stop riots, stop riots"
# '@PancakeBreasts Anon has been pretty awful through this whole thing'
# '@PrisonPlanet @dollaranarch What about drone killing innocent bystanders that are near an alleged bad guy?
# '@PancakeBreasts Oh for sure.. Anon has been exceptionally awful though!'
# Comment on "Assassination of Mike Brown"
# Reply to "Comment on 'Taint in the pants'"
# "Is Brown's past safe?"
# Brown robbery suspect didn't stop
# 'He went there.'
# The day #Ferguson cops told a dirty bloody lie (via @thedailybeast)
# The day #Ferguson cops told a dirty bloody lie
# 'It's not worth the bullets
# The Malatov cocktails
# 'It's hard to tell, but it's hard to tell
# '@Dostoevsky Shaze @140
# '@Dostoevsky Hade
# 'All weekend ppl will be talking about the "robbery" instead of the shooting
# "How many white celebrities have been CAUGHT shoplifting and end up dead in streets?"
# Comment on "A fucking racist"
# 'Hobby Lobby asks #Ferguson PD for clarification: 'Chopping off someone's hand is the maximum penalty for shoplifting'
# 'Where is the money if he robbed?
# '@kingpin7666 @CNNVideo smh'
# Is murder justified?
# 'Brwn Skin Girly robbed swishers supposedly'
# 'In 2009 #Ferguson police beat a man and charged him for bleeding on them'
# '@Jason__G99 @Koszik Meows @CNN Video exactly'
# '@Brwn Skin Girly @CNN Video Is It Necessary to be a Robbery?
# 'Tazing the cop with a gun and killing him'
# Why was #Mike Brownn shot to death in the first place?
# What the Ferguson PD and their PR machine can't do about it
# '@PublicOffender @CNNVideo Did I Say It Was Fake u Are U stupid or dumb?
# 'In what world do you let a cop who killed someone leave town?'
# How to shoot a teenager for possibly stealing a box of cigars
# '#Ferguson PD charged #Henry Davis w/ "destruction of property" for bleeding
# Why jaywalking and stealing cigars are capital crimes
# What's going on in the room of a black hole?
# Why he didn't know he was a suspect in fatal shooting of Michael Brown
# '@WesBellamy Yes, you read that right'
# SPOILER alert: died from multiple gunshot wounds
# Report: #Ferguson police beat up wrong suspect then charged him for getting blood on uniforms in 2009
# A Boon to My #Brane
# The #Ferguson Chief needs to be removed from his job
# Is There a Michael Brownian Theft?
# 'It's all in my head, but I don't know how to use it
# Why do #Ferguson PD look like stonewalls to counter punching?
# Comment on Analysis of the Cosmic Censorship''
# Truer words have never been spoken
# Reply to Comment on 'An insult to the Three Stooges''
# Brown didn't get the gun
# "What you're going with?"
# The DailyEdge @marstu67 :'Darren Wilson #Ferguson MO. (cop) who shot #Mike Brown
# I rolled through a stop sign
# "It wasn't really that bad"
# Comment on 'Stop and look at me' by Tim Wiseheart
# Comment on 'Analysis of the $Delta$-decay of a black hole'
# "It's not like he's on his knees with his hands up"
# Unconfirmed reports claim that Michael Essien has contracted Ebola
# '@LobittaT @FootballcomEN
# AC Milan midfielder Michael Essien has been diagnosed with Ebola
# Only photo I will tweet. CPR being performed on the soldier now
# Shots fired on parliament hill after a man walked up with a gun
# 'BREAKING - Shooting on Parliament Hill. RCMP have weapons drawn
# "Witness tells #CBCNews suspected shooter at #Ottawa's War Memorial"
# 'Ondertussen in Canada'
# 'RT @globalandmail: Shots fired at Parliament Hill
# "Shooter still on loose after uniformed soldier shot at War Memorial across road from Parliament"
# 'Gunfire inside Canadian parliament; soldier shot at National War Memorial in Ottawa
# 'BREAKING NEWS: At least 3 shots fired at Ottawa War Memorial
# 'One shot outside Centre Block in Parliament Hill'
# Why would you tweet the location of snipers?
# "Canada's Parliament Hill is on lockdown as police hunt shooting suspect"
# Sutcliffe's Theorem on Parliament Hill
# 'BREAKING: At least 20 shots have been fired in Ottawa
# The gunman in Ottawa has been shot and killed
# "I know what I'm doing here thank you"
# 'Shooting in Canadian Parliament comes day after ISIS-inspired radical killed in Canada'
# How about dropping bombs on Muslims all over the world?
# Why shouldn't a private citizen comment on a news event?
# More shots fired just off Parliament Hill. Police telling everyone to take cover
# 'It's locked down, I'm afraid
# '@HSolway @CBCAlerts We Are With You
# '@rcallimachi @ummsalama15_ sure yu just need to work for a jew'
# '@tdgecas @Henderburn well said @tdgecas
# 'Attack on Parliament: Soldier shot; gunman on the loose'
# "Here's that dramatic video via @josh_wingrove of shots fired inside parliament building"
# On the News Report I'm Watching
# Where have we come from?
# The University of Ottawa is now on lockdown
# '@Dmatthew Millar
# 'Recap: Gunman shot dead inside Parliament buildings
# Go police journalists, don't you think?
# 'Reports now that second shooter has been shot in downtown Ottawa #ottnews
# The Canadian soldier who was shot has died
# 'Ottawa Police Service: One shot at the Canada War Memorial
# '@beingbrad @SeedyRoads @AJEnglish
# "@PrideSky @CBCAlerts The tragedy is that we are allowing these people into our country"
# "Is there a black hole in the sky?"
# Ottawa Police report a third shooting at Rideau Centre no reports of injuries
# '@905 Fishing Guy @CBCAlerts Yes, they do
# Super scary "@BBCBreaking: Watching gunfire inside Canada's parliament in Ottawa"
# 'Heaven and Hell is right here on earth
# '@kellyoxford @HDMcC I had heard that before I saw you
# How should Twitter followers follow HDM?
# War Memorial Soldier pronounced dead just now
# The soldier who was shot in Ottawa Wednesday morning is a reservist serving in Hamilton'
# '@daxshepard1 @HDMcC THANK YOU
# '#Ottawa police confirm they are still seeking 1 or more suspects after shootings on Parliament Hill War Memorial nearby mall'
# Ont_Ombudsnanny @dmatthewmillar
# 'Hero. @LindaFrum @affanchowdhry absolutely!'
# The "five eyes" and western Europe "invite this misery still the perpetrators are despicable"
# '@TheKirkness Radio Canada tweeting same.
# '@Russell_Barth @dmatthewmillar @devo1400 @spaikin Not EVERYTHING will come out
# Sergeant-at-arms and Parliament Hill shootings
# Lies and Propaganda: Canada's Parliament locked down after shooting
# 'Statistics of Neutrino-Induced Steady State at Ottawa Hospital
# Game Postponed Not Cancelled
# "@JF_LaRue Yeah, interesting attack"
# #RCMP to hold news conference on #Ottawa shootings at 2 pm ET 11 am PT
# 'Candidate in Ottawa attacks to U.S. feds: ask for FBI assistance: Sr U.S. law enforcement official'
# Two shooting incidents in Ottawa: one at the war memorial the other on Parliament Hill
# '@CTVNews: Three shootings not long ago
# Reply to 'Comment on 'Analysis of the QCD coupling constant and its dependence on the geometry of the nucleon'
# 'RT @CBSNews: Police believe three gunmen were involved in shootings in Ottawa today
# FBI assisting in the case of the Ottawa shooting sources
# 'Is there a terrorist threat in the US?'
# Rejoinder to Mike SavageHFX
# 'It's all right, but it's hard to tell
# 'Sean Osmar @stephen_taylor So honoured to serve as Honorary Colonel in reserves'
# '#ISIS Media account posts picture claiming to be Michael Zehaf-Bibeau dead
# '#RIP Nathan CirillonRT @globandmail: Soldier killed at war memorial identified as Cpl. Nathan Cirillo
# Cpl. Nathan Cirillo of #HamOnt #ottawashooting
# RIP Nathan Cirillo
# Michael Zehaf-Bibeau and the Ottawa shooting
# 'BREAKING: Michael Zehaf-Bebeau's passport confiscation
# '@ChristoferU
# RIP Cpl. Nathan Cirillo
# RIP Nathan, we love you
# A Prayer for Nathan Cirillo
# Cpl. Nathan Cirillo: The Canadian soldier killed in today's Ottawa shooting
# '@AdamGuerbuez followed you because of this'
# Evening Grace: Is it real?
# "Principle in Toronto TONIGHT:n@3RDEYEGIRL tweeted today"
# "@PrinceTaughtMe I don't think it's even been on sale yet"
# How far is it from me?
# 'Prince fans at Massey Hall
# 'Prince Rumoured to be performing in surprise show in Toronto http://t.co/PEbtcmybqc
# 'Prince is playing a secret show
# "@LisaLaFlammeCTV yep don't know how I know but yep"
# When Prince is in Toronto'smh'
# 'OMG. #Prince Rumoured to be performing in Toronto today
# 'Clearly prince is having a show in toronto @TorontoComms #tdot #gta #prince #concert'
# Why does no one ever do secret shows in Ohio?
# Err twist?
# '@SBranisteanu @LiveNationON @masseyhall
# What tease?
# #BREAKING: Hostages are being held and a siege is happening
# "BREAKING: Live coverage of hostage situation unfolding in Sydney's Martin Place"
# ISIS flags remain on display in the cafe
# "DeVELOPING: Gunman Takes Hostages In Sydney Cafe 'ISIS' Flags Being Held Against Window"
# Black Islamic Flag in Window of #lindt Chocolate Store - Hostages Inside
# 'SYDNEY SIEGE: Gunman forces hostages to hold up ISIS flag in window
# Is there a "Islamic" flag?
# 'Are we done with it yet?'
# 'Several people held hostage at a Sydney cafe'
# A Sunni flag in window of Sydney Lindt cafe
# "@Does_It_Mata @BBCWorld"
# ISIS forcing Hostages to press ISIS flags against the Windows #DramaAlert HOT
# #BREAKING Hostages held inside Sydney cafe Islamic flag held up
# Geoblock lifted on #ABCNews24
# The Loner is Not Isis
# '@col_livesey @Basima Faysal @SkyNewsAust
# Hostages in Sydney cafe made to hold up Islamic flags
# Gunmen take hostages at Sydney cafe wave Islamic flag
# Siege in Sydney
# '@lhkahow @OZzSue @BBCWorld @BBCNews absolutely agree!!!'
# ''@BuzzFeedOz: Sydney Opera House evacuated concourse deserted
# Up to 20 held hostage in Sydney Lindt Cafe siege
# 'Statement from Prime Minister Tony Abbott on Sydney hostage situation'
# 'Full statement from PM Abbott on #Sydneysiege #Martin Place #Lindt
# Prehistoric evil cult murdered on trains and buses
# Prime Minister Tony Abbott's statement on the #SydneySiege
# Central Sydney shut down by police amid ongoing hostage situation
# 'Via @TheAnonMessage: nFIRST PHOTOS: Hostage pressed against a window
# Seven's picture of the gunman
# Preliminary reports indicate perpetrators appear to be members of #ISIS. #SydneySiege'
# #ISISAtacks #sydneyseige'
# The Hostage Site of Lindt Chocolat Cafe Near #Sydney Harbor
# "@RundfunkEuropa @RT_com well...you're just a silly paranoid fuck now"
# Comment on Howie-Dee's Theorem Revisited''
# '@FoxNews get off of Huckabee! Bring in @ShepNews Team'
# '@FoxNews We that respect freedom and property ownership'
# 'BREAKING UPDATE: Gunman says four devices are located around Sydney
# 'A black man wearing a black headband inside a cafe'
# AFP Live Report: "Police stand guard as hostages"
# "Canada's thoughts and prayers are with our Australian friends," tweeted #pmharper
# 'We sacrifice ourselves for you O Mohamed'
# Approximately 50 hostages may be held captive at #Lindt café
# The Sydney cafe siege may be part of a larger plot
# JustsayingDMY @SkyNewsAust wsy too many pc apologists
# 'Way uncool @Uber_Sydney
# 'A bit like Hadley then?'
# Its about chocolate!' '@AP Little LATE on the ball isn't it?
# Uber says it has hiked prices in Sydney to encourage more drivers to come online&amp; pick up passengers
# '#SYDNEYSIEGE: Hostage-takers 'have suicide belts ‘have a radio convo with #Abbott'
# 'Uber Sydney trips from CBD will be free for riders'
# '@Shoq Typical @RT_com BS'
# Hey Aussie Sheeple wanna invade the middle east because of one wack job
# What do you think about Abbott's gov't?
# Uber is covering the cost of all rides
# '@universe93 but you do Uber for trying to increase drivers'
# Uber is still charging drivers higher fares to encourage riders to ride faster
# "We are your soldiers O Muhammad"
# '@ehammonds @Uber_Sydney still looks like a PR issue
# Faster backflip than Tony Abbott
# 'It's hard to see people coming out of fire doors
# #ChangeTip #SydneySeige
# MT @BreakingNews: Three people appear to escape from Martin Place Sydney café amid hostage situation
# BREAKING: Three hostages appear to have escaped the Sydney cafe where a siege remains ongoing
# 'RT @ABC: Police: Negotiators are now in contact with armed hostage-taker in #Sydney situation'
# Comment on Analysis of the Cosmic Microwave Background Radiation'' by Cameron Atfield
# Isis is the only way to survive
# How many people have been able to get out of cafe during hostage?
# '@Uber_Sydney @COMINT_AU
# A shot that captures the #sydneysiege: sheer terror/relief of escaped hostages
# Report of gunman claiming four packages around Sydney
# Five Hostages Escape Sydney Cafe Siege - Live Updates From @BuzzFeedOz
# How awful is it to be able to do something so hard?
# Hostage taker in Sydney cafe demands ISIS flag and call with Australian PM Sky News reports
# 'Five hostages have escaped the besieged Lindt Cafe
# 'NSW Police confirm 5 hostages have emerged from the #sydneysiege'
# '@andrewv @bmac_ottawa @Uber_Sydney
# Myths around Sydneysiege debunked
# '@SkyNews Its the right thing to do' '@SkyNews But the Daily Mail is showing their faces'
# The hostage video of the 'SydneySiege' collider
# 'Anything is possible'
# 'Sydney Hostage-TAKER': A man accused of sexual assaulting 7 women
# 'Escaped #SydneySiege hostage': Elly Chen
# Several more hostages flee from cafe under siege in Sydney local media
# 'POLICE MOVE IN: Live ammunition used in Martin Place #sydneysiege'
# #MartinPl. #SydneySiege #9News'
# '"@RT_com: BREAKING: Police enter #Lindt cafe hostages flee
# 'BREAKING @Sky Business: freed hostage borne high from #sydneysiege w/c.4 paramedic teams on the scene
# Hostages fleeing #Sydney cafe held by Iranian gunman
# 'Sydney siege: police enter cafe as hostages flee gunfire'
# "Not a good time to shoot"
# 'Sydney Siege' revisited
# GUNMAN IS DOWN
# Comment on 'Sydney dominating the flash but not the flash'
# 'Sick deranged *expletive* looking for suicide by cop'
# '“@LandODaFree: Unreal. Like a movie
# The #SydneySiege is Over
# At least two people have died following the #SydneySiege. 5 people are being treated by paramedics.” NO PLEASE'
# '#sydneysiege is over. 2 confirmed dead #PrayForSydney Hostages #Sydney #hostages'
# The Sydney Siege is Almost Over
# '@TexasJew No idea but Muslim terrorists do love their explosives'
# Comment on "Jehovah's Witness Extremism in the Sky"
# 10 dead after shooting at HQ of satirical newspaper #CharlieHebdo
# How dreadful is 'Nowhere is safe anymore'
# "We're gonna avenge our prophet"
# More tragedy: Eleven dead in shooting at Paris offices of satirical magazine Charlie Hebdo
# 'BREAKING Charlie Hebdo latest: 11 dead 10 wounded (five critical) two gunmen unaccounted for
# "@AFP photo: #CharlieHebdo - 11 dead including 2 police in Paris shooting"
# At least 11 dead in shooting at HQ of #CharlieHebdo in Paris
# 11 confirmed dead Francois Hollande to visit scene of attack
# Curly wurlys and half avocados
# 'Paris terrorist attack on Charlie Hebdo
# At least 12 killed in today's attack on satirical magazine #CharlieHebdo
# '@Colvinius @LePoint tragedy :( :( #CharlieHebdo')
# 12 dead in #CharlieHebdo attack in Paris
# 'Nancy Saidboo at Colvinius and LePoint
# ANTI-Muslims and Jesus
# Extremism and Terrorism Has No Place in Islam #ParisAttack
# "@WSJ Islam. That's the only info you need. Islam. #CharlieHebdo"
# 'hassanbasmer @Mariodinava @DaliaChai
# "Bigotry: The Dark Danger"
# "Every Charlie Hebdo cartoonist is killed"
# 'And 8 anonymous. RT@HuffPostUK:4 #CharlieHebdo cartoonists killed:n- Charbn- Cabun- Tignousn- Wolinskin#JeSuisCharlie
# Video show two #CharlieHebdo attackers wearing hoods &amp; black clothing shoot a wounded man
# 'URGENT: 3 gunmen involved in deadly attack on #CharlieHebdo
# 'Paris Manhunt: 3 #CharlieHebdo attackers with AK-47 rifles &amp; reportedly rocket-propelled grenade still at large http://t.co/3Jsosc7yl3'
# The Charlie Hebdo gunmen identified themselves as members of al-Qaida
# "Most compelling image I've seen to come out of horrifying events in Paris courtesy of Banksy"
# Banksy gets it right
# Banksy says #JeSuisCharlie in a beautiful way
# R.I.P. Ahmed Merabet a French Muslim Cop first victim of #CharlieHebdo attack
# "I'll give you that"
# Two shot in Paris including traffic cop as manhunt continues for #CharlieHebdo suspects
# On the #CharlieHebdo attack by @LucilleClerc
# "French police: Said Kouachi and Cherif Kouachi wanted in Paris terror attack: the face of cowards"
# The #CharlieHebdo attack suspects have reportedly fired shots while robbing a petrol station
# The last person killed in Charlie Hebdo attacks was a Muslim police officer
# Andreemurphy 't Hooft'
# 'Paris says highest alert level extended north to region where attack suspects spotted'
# "Clarissa 27 years old police trainee of Montrouge Police in #France"
# '@BBCWorld n#Stop Killing Innocent Peoplen#FreePalestinen#free Burman#freeSyria
# Reports of shooting at Dammartin en Goele
# 'Car chase under way in Paris as gunfight breaks out
# 'BREAKING: Shots fired hostages in manhunt for #CharlieHebdo attackers
# 'Police convoy and helicopters are rushing to scene to arrest Charlie Hebdo massacre suspects'
# 'DEVELOPING: Police pursuing #CharlieHebdo shooting suspects helicopters deployed - LIVE FEED: http://t.co/GRxHibEau2 http://t.co/pDlmmCax1B'
# 'Siege: "@FRANCE24: #BREAKING : 1 dead several injured in shootout North-East of Paris"
# 'Je Suis Charlien#UnsucessfulFrancePolicen#Dammartin EnGoele n#CharlieHebdo n#IncompetentFrancePolicen#Parisburning 20 Dead,2 injured'
# '@TIME 1 hostage/war zone in Dammartin
# 'They wont be martyrs. They won't die because of their religion'
# '@RT_com: #CharlieHebdo shooting suspects tell police they 'prepared to die as martyrs'
# Suspects in #CharlieHebdo attack
# 'Are 2 #CharlieHebdos holed up in an industrial estate?
# 'Is this the same Islamic terrorists that killed a couple days ago?'
# '@NickK60 @BBC Breaking Well
# An unnamed source says the killing of the policewoman in Paris is linked to the #CharlieHebdo attack
# The 144 virgins to line up in France
# '@SkyNewsBreak really sad situation'
# '#BREAKING Gunman in policewoman killing suspected in new Paris hostage-taking: source'
# 'RT @FRANCE24 #BREAKING - At least five hostages in Paris kosher supermarket: (AFP) https://t.co/ZF6TGUkOdn #Vincennes
# 'MORE: France: Shooting hostage-taking at kosher market in Paris
# TopoC: "I'm sorry, I can't do that"
# An 11-month old baby is among the hostages at the Kosher supermarket in Paris
# @FoxNews @AFP Awesome!!!
# French police publish photos of suspect in Thurs Montrouge shooting
# Or the day you wondered why you didn't just study creative writing and adopt some nice cats in Vermont
# The connection between the Kosher store and charlie hebdo shooters
# 'Well done, but what will you do about it?' -- Gunman in kosher grocery store is demanding the release of the suspects in #CharlieHebdo shooting
# The horror continue
# #JeSuisJuif 'An Israeli woman holds a baby hostage in a supermarket'
# Breaking: Two hostage situations in France are linked Paris prosecutor says
# '@Cultiv8Hope @ABC @VeraSweeney
# 'Who buys Kosher?'
# On a gunman threatens to kill five hostages in Paris market
# Breaking: Gunman at Paris store threatens to kill hostages if #CharlieHebdo suspects are harmed
# 'Hostage-taker at Paris store demands release of #Kouachis police union spoke
# '@DAVIDDMDRAIMAN @marrty96
# '#Charlie Hebdo killers shot dead by police'
# Two Charlie Hebdo suspects killed as police storm building
# "BREAKING: Charlie Hebdo gunmen's hostage freed and safe after police assault"
# ''Police taking people out of #Paris grocery where hostages were being held
# '@vega_shelly @cnnbrk fingers crossed
# 'AFP: suspected #CharlieHebdo gunmen have been killed'
# Some good news!
# '@Daroff 4 people reported dead of six hostages
# Token indices sequence length is longer than the specified maximum sequence length for this model (749 > 512). Running this sequence through the model will result in indexing errors
# Several hostages freed at Jewish supermarket in Paris
# Several hostages freed at Jewish supermarket in Paris
# Hostage-taker in supermarket siege killed reports say
# '@ensowi @France24_en Yes but think it was too dangerous'
# 'Coup in #Russia?
# 'US Embassy #Moscow cables talk about an operation planned by "dissidents" in #Russia to "overthrow Putin"
# Had Boris Nemtsov been killed by Ramzan Kaladyrov?
# Swiss Rumors: Putin absence due to girlfriend Alina giving birth in Ticino
# What makes us think the baby story may be true?
# "@MailOnline never!!"
# Comment on 'Coup?'
# 'Unformed Russian Embassy staff in London have left for Putin HAS DIED!'
# '@AdaptToReality @batchelorshow Yeah
# '@TAW3333 Emm I never tagged the user
# "Putin reappears on television"
# 'Very good on #Putin coup by @CoalsonR: Three scenarios for a succession in Russia
# Looking for Narnia with Vladimir Putin
# Germanwings Airbus A320 crashes in French Alps near Digne
# 'BREAKING: 148 passengers were on board #GermanWings Airbus A320 which has crashed in the southern French Alps
# 'Accident aircraft looks to be Germanwings flight 9525 Barcelona to Dusseldorf
# The German Wings flight in the southern Alps
# German Wings tweeting about plane crashing in French Alps with 148 on board
# Germanwings passenger plane crashes in France: http://t.co/BSJhGgMChG
# Germanwings plane crashes in southern France up to 150 feared dead
# 'Flight #4U9525: A High-Redshift, Low-Energy Flight'
# '@Granabanana I know that!'
# A tragedy for the families and friends of the plane passengers and crew of Airbus A320
# '1047 call: DGAC source says pilots had "emergency emergency"
# '@AirSmolik Im thinking structurql failure - qnd then depressure etc?
# Debris from #Germanwings crash in Barcelonette area of the Alps
# Are the #Germanwings #A320 plane survivors?
# Debris from #Germanwings crash located in Barcelonette area of the Alps
# 'Latest on #Germanwings crash: Pilots signaled 911 before dropping out of midair"
# '#Germanwings passenger plane crashes in French Alps with 148 onboard
# "Ohhh man terrible news for all the victims' families"
# How tragic is the Germanwings crash?
# 'Victims of #Germanwings crash were most likely from Spain Germany &amp; Turkey says French President Hollande
# "Support Israel the apple of God's eye"
# '@RichelleVHP Safety record is not perfect
# "@madest @fox and friends Douchey it's Douchey"
# How did #4U9525 descend?
# Co-Pilot Locked Out Of Cockpit Before Fatal Plane Crash
# 'Names of pilots rumored to be Patrick Sonderheimer with co-pilot Andreas Lubitz - No formal confirmation yet
# '#4U9525: Robin Lubitz is the copilot in the flight deck who crashed the aircraft'
# "It's a mystery, I can't tell you what happened"
# Can any muslim be trusted near an airplane now?
# I wouldn't put anybody on a bus with a muslim driver much less a plane
# RT @khjelmgaard: German media reporting #Andreas Lupitz had a "serious depressive episode" six years ago
# 'Hero of Islamic State'
# type of list_of_reply: <class 'list'>
# Unnamed: 0                    int64
# in_reply_to_status_id_str     int64
# label                        object
# text_list                    object
# generated_reply              object
# dtype: object

# %%
support_df
# Out:
#      Unnamed: 0  in_reply_to_status_id_str    label  \
# 0             1         498280126254428160  support
# 1             3         498430783699554305  support
# 2             5         498433698149056513  support
# 3            12         499366666300846081  support
# 4            16         499368931367608320  support
# ..          ...                        ...      ...
# 422        2121         581075660690575360  support
# 423        2128         581293286268129280  support
# 424        2132         581298086246395904  support
# 425        2136         581386094337474560  support
# 426        2140         581473088249958400  support
#
#                                              text_list  \
# 0    ['“@MichaelSkolnik: Mike Brown was staying wit...
# 1    ['@MichaelSkolnik @AC_BOwen #Cleveland @CivilR...
# 2    ['@Supreme___Power @MichaelSkolnik You so edgy.']
# 3    ["Line of police cars with high beams on greet...
# 4    ["@clydetheslyde @moiskd Imagine if Ferguson f...
# ..                                                 ...
# 422  ["@marcepa49 The autopilot wasn't set to 100 f...
# 423  ['@daxtonbrown @ItsJustJill. It took long enou...
# 424  ["@daxtonbrown @AnewTrackrecord @ShamNaarai I ...
# 425  ["RT @khjelmgaard: German media reporting #And...
# 426  ['@jjauthor @gatewaypundit i knew that scarf h...
#
#                                        generated_reply
# 0    'Mike Brown was staying with his grandmother f...
# 1    'Witness: Police stopped Mike Brown after yell...
# 2        '@Supreme__Power @Michael Skolnik You so edgy
# 3    The line of police cars with high beams on #Fe...
# 4                 Footprints of the #Ferguson protests
# ..                                                 ...
# 422   "It's a mystery, I can't tell you what happened"
# 423    Can any muslim be trusted near an airplane now?
# 424  I wouldn't put anybody on a bus with a muslim ...
# 425  RT @khjelmgaard: German media reporting #Andre...
# 426                            'Hero of Islamic State'
#
# [427 rows x 5 columns]

# %%
support_df.to_csv('temp_support.csv')

s2 = pd.read_csv('/content/support_tweets.csv')
# new_support_df = pd.merge(support_df, s2)
# support_df[''].to_csv('support_input.csv')

# %%
df_temp = df.groupby(by=['in_reply_to_status_id_str', 'label'])['text'].apply(list).reset_index(name='text_list')
df_temp
# Out:
#       in_reply_to_status_id_str    label  \
# 0            498280126254428160  comment
# 1            498280126254428160  support
# 2            498430783699554305  comment
# 3            498430783699554305  support
# 4            498432131669192704  comment
# ...                         ...      ...
# 2138         581473088249958400  comment
# 2139         581473088249958400    query
# 2140         581473088249958400  support
# 2141         581573165492523008     deny
# 2142         581574401411457024  comment
#
#                                               text_list
# 0     [@MichaelSkolnik -- wow, @MichaelSkolnik Unbel...
# 1     [“@MichaelSkolnik: Mike Brown was staying with...
# 2     [@MichaelSkolnik cool! Darkskinned man is a cr...
# 3     [@MichaelSkolnik @AC_BOwen #Cleveland @CivilRi...
# 4     [@Agent_Kindi&lt;&lt;&lt;&lt; @SecretService I...
# ...                                                 ...
# 2138  [@jjauthor @gatewaypundit. I knew it! Those cr...
# 2139  [@jjauthor @gatewaypundit Isn't Islam a wonder...
# 2140  [@jjauthor @gatewaypundit i knew that scarf he...
# 2141  [@EdWardMDBlog @USATODAY @khjelmgaard all rumo...
# 2142  [@tinkalee_12 @USATODAY @khjelmgaard My 2nd so...
#
# [2143 rows x 3 columns]

# %%
# parent_id_tweet_df = df[['in_reply_to_status_id_str', 'parent_tweet_text']]
# parent_id_tweet_df = parent_id_tweet_df.drop_duplicates()
# parent_id_tweet_df

parent_id_tweet_dict = dict(zip(df.in_reply_to_status_id_str, df.parent_tweet_text))
parent_id_tweet = {'id':(list(parent_id_tweet_dict.keys())), 'parent_tweet':(list(parent_id_tweet_dict.values()))}
pt = pd.DataFrame.from_dict(parent_id_tweet)

# df_temp['source_tweet'] = df['in_reply_to_status_id_str'].map(parent_id_tweet_dict)
# df_temp

support_df['source_tweet'] = support_df['in_reply_to_status_id_str'].map(pt.set_index('id')['parent_tweet'])
support_df
# Out:
#      Unnamed: 0  in_reply_to_status_id_str    label  \
# 0             1         498280126254428160  support
# 1             3         498430783699554305  support
# 2             5         498433698149056513  support
# 3            12         499366666300846081  support
# 4            16         499368931367608320  support
# ..          ...                        ...      ...
# 422        2121         581075660690575360  support
# 423        2128         581293286268129280  support
# 424        2132         581298086246395904  support
# 425        2136         581386094337474560  support
# 426        2140         581473088249958400  support
#
#                                              text_list  \
# 0    ['“@MichaelSkolnik: Mike Brown was staying wit...
# 1    ['@MichaelSkolnik @AC_BOwen #Cleveland @CivilR...
# 2    ['@Supreme___Power @MichaelSkolnik You so edgy.']
# 3    ["Line of police cars with high beams on greet...
# 4    ["@clydetheslyde @moiskd Imagine if Ferguson f...
# ..                                                 ...
# 422  ["@marcepa49 The autopilot wasn't set to 100 f...
# 423  ['@daxtonbrown @ItsJustJill. It took long enou...
# 424  ["@daxtonbrown @AnewTrackrecord @ShamNaarai I ...
# 425  ["RT @khjelmgaard: German media reporting #And...
# 426  ['@jjauthor @gatewaypundit i knew that scarf h...
#
#                                        generated_reply  \
# 0    'Mike Brown was staying with his grandmother f...
# 1    'Witness: Police stopped Mike Brown after yell...
# 2        '@Supreme__Power @Michael Skolnik You so edgy
# 3    The line of police cars with high beams on #Fe...
# 4                 Footprints of the #Ferguson protests
# ..                                                 ...
# 422   "It's a mystery, I can't tell you what happened"
# 423    Can any muslim be trusted near an airplane now?
# 424  I wouldn't put anybody on a bus with a muslim ...
# 425  RT @khjelmgaard: German media reporting #Andre...
# 426                            'Hero of Islamic State'
#
#                                           source_tweet
# 0    Every 28 hours a black male is killed in the U...
# 1    .@AP I demand you retract the lie that people ...
# 2    @MichaelSkolnik @Agent_Kindi @Supreme___Power ...
# 3    Currently the #FoxNews website has zero, repea...
# 4    St. Louis Co Police tell me ofcr shot a man wh...
# ..                                                 ...
# 422  @Minus777 @flightradar24 @isobelroe Look at th...
# 423  Germanwings co-pilot had serious depressive ep...
# 424  @daxtonbrown @ShamNaarai @AnewTrackrecord a mu...
# 425  GERMAN NEWS REPORT: Co-Pilot of Germanwings Ai...
# 426  Anyone who knows Marina Joyce personally knows...
#
# [427 rows x 6 columns]

# %%
support_df[['source_tweet', 'generated_reply']].to_csv('input_support.csv')

# %% [markdown]
# # TRAINING THE GENERTAED I/P FILE FOR SUPPORT

# %%
# !pip install simplet5
# Out:
# Collecting simplet5
#   Downloading simplet5-0.1.4.tar.gz (7.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from simplet5) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from simplet5) (1.3.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 4.8 MB/s
# Requirement already satisfied: torch!=1.8.0,>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from simplet5) (1.11.0+cu113)
# Collecting transformers==4.16.2
#   Downloading transformers-4.16.2-py3-none-any.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 41.7 MB/s
# Collecting pytorch-lightning==1.5.10
#   Downloading pytorch_lightning-1.5.10-py3-none-any.whl (527 kB)
#      |████████████████████████████████| 527 kB 49.9 MB/s
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 45.0 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->simplet5) (4.2.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->simplet5) (2.8.0)
# Collecting setuptools==59.5.0
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      |████████████████████████████████| 952 kB 41.7 MB/s
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->simplet5) (21.3)
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.8.2-py3-none-any.whl (409 kB)
#      |████████████████████████████████| 409 kB 53.2 MB/s
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 46.3 MB/s
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->simplet5) (6.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->simplet5) (4.64.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->simplet5) (4.11.3)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->simplet5) (0.12.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->simplet5) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->simplet5) (2019.12.20)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->simplet5) (0.6.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 38.0 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->simplet5) (3.6.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 44.1 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning==1.5.10->simplet5) (3.0.8)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (3.17.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (3.3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (1.44.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (1.0.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (1.35.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.16.2->simplet5) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.16.2->simplet5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.16.2->simplet5) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.16.2->simplet5) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.16.2->simplet5) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (3.2.0)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 2.9 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 46.3 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 49.6 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->simplet5) (21.4.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->simplet5) (2.0.12)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->simplet5) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->simplet5) (2.8.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.16.2->simplet5) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.16.2->simplet5) (1.1.0)
# Building wheels for collected packages: simplet5, future, sacremoses
#   Building wheel for simplet5 (setup.py) ... done
#   Created wheel for simplet5: filename=simplet5-0.1.4-py3-none-any.whl size=6873 sha256=b83bc9b91928189f6ea3bafc423d14a2068dfd63e2ec3d212c9498e58eef7447
#   Stored in directory: /root/.cache/pip/wheels/30/1b/96/47ad5fda68def6635961fd0ca312fc0ce3670936ae09d97c43
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=c8d365e617f34ecd3e8f509e04e9303e671bdc09e67ae98552c52f422b9dd94b
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=8979d03b4cd1290e78cdf127892db0304af1997ea18459ccf0ad812cdabebc45
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built simplet5 future sacremoses
# Installing collected packages: setuptools, multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, pyDeprecate, fsspec, aiohttp, torchmetrics, sacremoses, future, transformers, sentencepiece, pytorch-lightning, simplet5
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.19.0
#     Uninstalling transformers-4.19.0:
#       Successfully uninstalled transformers-4.19.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.3.0 future-0.18.2 multidict-6.0.2 pyDeprecate-0.3.1 pytorch-lightning-1.5.10 sacremoses-0.0.53 sentencepiece-0.1.96 setuptools-59.5.0 simplet5-0.1.4 torchmetrics-0.8.2 transformers-4.16.2 yarl-1.7.2

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

path = "/content/input_support.csv"
df = pd.read_csv(path)


# simpleT5 needs dataframe to have 2 columns: "source_text" and "target_text"
df = df.rename(columns={"generated_reply":"target_text", "source_tweet":"source_text"})
df = df[['source_text', 'target_text']]


df['source_text'] = "summarize: " + df['source_text']
df
# Out:
#                                            source_text  \
# 0    summarize: Every 28 hours a black male is kill...
# 1    summarize: .@AP I demand you retract the lie t...
# 2    summarize: @MichaelSkolnik @Agent_Kindi @Supre...
# 3    summarize: Currently the #FoxNews website has ...
# 4    summarize: St. Louis Co Police tell me ofcr sh...
# ..                                                 ...
# 422  summarize: @Minus777 @flightradar24 @isobelroe...
# 423  summarize: Germanwings co-pilot had serious de...
# 424  summarize: @daxtonbrown @ShamNaarai @AnewTrack...
# 425  summarize: GERMAN NEWS REPORT: Co-Pilot of Ger...
# 426  summarize: Anyone who knows Marina Joyce perso...
#
#                                            target_text
# 0    'Mike Brown was staying with his grandmother f...
# 1    'Witness: Police stopped Mike Brown after yell...
# 2        '@Supreme__Power @Michael Skolnik You so edgy
# 3    The line of police cars with high beams on #Fe...
# 4                 Footprints of the #Ferguson protests
# ..                                                 ...
# 422   "It's a mystery, I can't tell you what happened"
# 423    Can any muslim be trusted near an airplane now?
# 424  I wouldn't put anybody on a bus with a muslim ...
# 425  RT @khjelmgaard: German media reporting #Andre...
# 426                            'Hero of Islamic State'
#
# [427 rows x 2 columns]

# %%
training_df, test_df = train_test_split(df, test_size=0.2)
training_df.shape, test_df.shape
# Out:
# ((341, 2), (86, 2))

# %%
from simplet5 import SimpleT5

model = SimpleT5()
model.from_pretrained(model_type="t5", model_name="t5-base")
model.train(train_df=training_df[:5000],
            eval_df=test_df[:100], 
            source_max_token_len=128, 
            target_max_token_len=50, 
            batch_size=8, max_epochs=3, use_gpu=True)
# Out:
# Global seed set to 42
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5_fast.py:161: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   copyfile(self.vocab_file, out_vocab_file)
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Missing logger folder: /content/lightning_logs
#
#   | Name  | Type                       | Params
# -----------------------------------------------------
# 0 | model | T5ForConditionalGeneration | 222 M
# -----------------------------------------------------
# 222 M     Trainable params
# 0         Non-trainable params
# 222 M     Total params
# 891.614   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Global seed set to 42
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]

# %%
# let's load the trained model for inferencing:
model.load_model("t5","/content/outputs/simplet5-epoch-2-train-loss-2.8294-val-loss-3.2814", use_gpu=True)


text_to_summarize = """
@FRANCE24: #BREAKING - At least five hostages in Paris kosher supermarket: (AFP) https://t.co/xFn05puuBm #Vincennes http://t.co/WU3kmq957e
RT @FRANCE24 #BREAKING - At least five hostages in Paris kosher supermarket: (AFP) https://t.co/ZF6TGUkOdn #Vincennes http://t.co/501nakgVKN
@FRANCE24 @HarrietBaldwin It's time 4 West 2 make formal declaration of war vs Islamic Terrorists but is there country with courage 2 do so?
@FRANCE24 is this all part of a plan .. a spread of attacks by different associates  to cause maximum confusion ..playing hostages . Max PR?
"""

summarized_text = model.predict(text_to_summarize)[0]
summarized_text
# Out:
# '@FRANCE24: #BREAKING - At least five hostages in Paris kosher supermarket: (AFP) https://t.co/ZF6TGUkOdn'

# %%
# sample text --> Steve Jobs Wanted Original iPhone to Have No SIM Card Slot, Says Former iPod VP: Rumors have suggested Apple could soon release an iPhone without a physical SIM card slot, and it turns out that if that's accurate, Apple would be… https://macrumors.com/2022/05/13/original-iphone-was-meant-to-be-simless/?utm_source=dlvr.it&utm_medium=twitter #Apple #Mac #Rumors

# %%
#BLEU_SCORE

from nltk.translate.bleu_score import sentence_bleu

ref_list = text_to_summarize.splitlines()
reference = [i.split() for i in ref_list]


candidate = summarized_text.split()

print('Individual 1-gram: %f' % sentence_bleu(reference, candidate, weights=(1, 0, 0, 0)))
print('Individual 2-gram: %f' % sentence_bleu(reference, candidate, weights=(0, 1, 0, 0)))
print('Individual 3-gram: %f' % sentence_bleu(reference, candidate, weights=(0, 0, 1, 0)))
print('Individual 4-gram: %f' % sentence_bleu(reference, candidate, weights=(0, 0, 0, 1)))

score = sentence_bleu(reference, candidate, weights=(0.25, 0.25, 0.25, 0.25))
print(score)
# Out:
# Individual 1-gram: 0.857404
# Individual 2-gram: 0.857404
# Individual 3-gram: 0.857404
# Individual 4-gram: 0.857404
# 0.8574039191604413
